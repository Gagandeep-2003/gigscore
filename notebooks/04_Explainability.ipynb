# %% [markdown]
# # 🔍 GigScore — Model Explainability
#
# This notebook demonstrates SHAP-based explainability:
# 1. Global feature importance (mean |SHAP|)
# 2. Local explanations (per-applicant SHAP waterfall)
# 3. Reason code generation
# 4. Fairness audit visualization

# %%
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '..')

# Load a trained model (after running training notebook)
# Or train a quick one here
print('Load trained artifacts or run 03_Model_Training first')

# %% [markdown]
# ## Global Feature Importance
# Shows which features matter most across ALL predictions.
#
# ```python
# explainer = GigScoreExplainer(model, feature_names)
# importance_df = explainer.global_feature_importance(X_test)
# ```

# %% [markdown]
# ## Local Explanation (Single Applicant)
# Shows exactly which features pushed THIS applicant's score up or down.
#
# ```python
# explanation = explainer.explain_prediction(X_test[0])
# print('Positive factors:', explanation['positive_factors'])
# print('Negative factors:', explanation['negative_factors'])
# ```
